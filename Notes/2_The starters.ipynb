# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Intendation - Tab spaces or space bar
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# This code shows how to use comments 
# but actually it performs multiplying two numbers
 
a=21
b=45
print(a*b)
# Out:
# 945

# %%
''' if you think the normal comments using hash is boring
you can use these multiline comments
its the same as multiline string in python
thankyou 
'''

'''
and this code performs
exponent
'''

a=3
b=2
print(a**b)
# Out:
# 9

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
int_var = 21
str_var = 'hype'
float_var = 34.53
bool_var = True

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
alpha = 213
alph01 = 321
alph_01 = 921
_01alph = 90
age = 31
weight = 65

# %%
1_alph= 21
in = 32
with = '23'
jfvfv = 23
*s&^hs=12
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_2468\1918752333.py", line 2
#     in = 32
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # ![image.png](attachment:image.png)
