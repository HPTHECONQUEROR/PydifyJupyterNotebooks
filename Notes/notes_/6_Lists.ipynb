# %% [markdown]
# # Lists

# %%
#Lists are mutable in python
#mutable - values can be changes individually
#sequence of values which are seperated using comma which are inside square brackets is called as a list

a=[1,'df']
a[1] = 2
a
# Out:
# [1, 2]

# %%
lst=['a','x',',',True,False,1,1.2]
lst[2]=2
lst
# Out:
# ['a', 'x', 2, True, False, 1, 1.2]

# %%
#accesing an element in alist using index
lst=[21,'a',True,4.3]
print(lst[3])
# Out:
# 4.3

# %%
#creating a list using list function
a=1,2
a
# Out:
# (1, 2)

# %%
a=list(a)

print(a)
# Out:
# [1, 2]

# %%
#Slicing in list
lst=[11,32,1,3,4,50,1,0]
#    0  1  2 3 4 5  6 7
#the same as range function lst[start,end,step]
#list[first,last,stepping]
#range(first,last,stepping)
lst[1:5:2]
# Out:
# [32, 3]

# %%
lst[-1:-5:-1]
# Out:
# [0, 1, 50, 4]

# %%
#some methods in list
a=[4,3,1,2,3]

# %%
a.count(3)
# Out:
# 2

# %%
a = [5,11,2,10,1111]
a.sort()
print(a)

sorted(a,reverse=True)
print(a)
# Out:
# [2, 5, 10, 11, 1111]
# [2, 5, 10, 11, 1111]

# %%
s = "Hello"
s = s.replace("H","j") # copy of s = jello
print(s)
# Out:
# Hello

# %%
sorted(a,reverse = True)
# Out:
# [4, 3, 3, 2, 1]

# %%
a = [2,4,5,3,6,7,3,8,9,10]
a.remove(3)
a
# Out:
# [2, 4, 5, 6, 7, 3, 8, 9, 10]

# %%
a=[1,1,3,4,4,4,4,5,6,6] #1,3,4,4,5,6
for num in a:
  for _ in range(a.count(num)-1):
    a.remove(num)
print(a)
# Out:
# [1, 3, 4, 5, 6]

# %%
list1 = [1, 3, 4, 5, 6]
list1.append(34)
print(list1)
# Out:
# [1, 3, 4, 5, 6, 34]

# %%
a=[4,3,1,2,3]
a.remove(3) #removes the first element with value 3
a.pop(3) #removes the element at index 3
a
# Out:
# [4, 1, 2]

# %%
a=[4,3,1,2,3]
del(a[2])
a
# Out:
# [4, 3, 2, 3]

# %%
del(a)
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4476\3613880318.py in <module>
#       1 del(a)
# ----> 2 a
#
# NameError: name 'a' is not defined

# %%
#cloning
lis=[1,2,3,4,5,6,9]
lis2=lis
print(lis)
print(lis2)
# Out:
# [1, 2, 3, 4, 5, 6, 9]
# [1, 2, 3, 4, 5, 6, 9]

# %%
lis3=lis[2:7:2]
lis3
# Out:
# [3, 5, 9]

# %%
#nested list
lis=[[1,2,3],5,7,4]
#       0    1 2 3
for i in lis:
    print(i)
# Out:
# [1, 2, 3]
# 5
# 7
# 4

# %%
#list operations
lis=[2,5,2,1]
lis2=[4,2,5]
len(lis)
# Out:
# 4

# %%
new_list = lis+lis2 #concatenation
print(new_list)
# Out:
# [2, 5, 2, 1, 4, 2, 5]

# %%
lis*4 #repition
# Out:
# [2, 5, 2, 1, 2, 5, 2, 1, 2, 5, 2, 1, 2, 5, 2, 1]

# %%
if 1 in lis:
    print('happy')
else:
    print('sad')
# Out:
# happy

# %%
10 in lis
# Out:
# False

# %%
max(lis)
# Out:
# 5

# %%
sum(lis)
# Out:
# 10

# %%
list1 = [1,2,3]
