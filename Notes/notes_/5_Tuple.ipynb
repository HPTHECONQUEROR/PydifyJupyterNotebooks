# %% [markdown]
# # Tuple

# %% [raw]
# 1.Tuples are immutable
# 2.Its a sequence of values declared in between ()
# 3.ex:(1,2,3)

# %% [markdown]
# # Singleton Tuple

# %%
t = ([1,2,3],[2,3],1,"2",True)
for i in t:
    print(i)
# Out:
# [1, 2, 3]
# [2, 3]
# 1
# 2
# True

# %%
lst1 = [1,4,3]
lst1[1] = 54
print(lst1)
# Out:
# [1, 54, 3]

# %%
str1 = "Hihello"
str1[0] = "i"
str1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 str1 = "Hihello"
# ----> 2 str1[0] = "i"
#       3 str1
#
# TypeError: 'str' object does not support item assignment

# %%
tup1 = (1,4,3)
tup1[0] = 23
tup1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 tup1 = (1,4,3)
# ----> 2 tup1[0] = 23
#       3 tup1
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=(True,)
type(t)
# Out:
# tuple

# %%
u='end',
type(u)
# Out:
# tuple

# %%
u=1,
type(u)
# Out:
# tuple

# %% [markdown]
# # Accesing tuple elements

# %%
tup=(1,4,5,'w',2.3,True,6,8,21) 
#    0 1 2  3   4   5    6 7 8

# %%
tup[5]
# Out:
# True

# %%
tup[::-1]
# Out:
# (21, 8, 6, True, 2.3, 'w', 5, 4, 1)

# %%
tup[len(tup)-1]
# Out:
# 21

# %%
tup[4]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15820\2352529081.py in <module>
# ----> 1 tup[4]=5
#
# TypeError: 'tuple' object does not support item assignment

# %%
lis=[3,4,5]
lis[2]=9
lis     #but lists are mutable
# Out:
# [3, 4, 9]

# %%
#Concatenation
tup1=(4,1,3) 
tup2=(9,0,2) 
tup1+tup2
# Out:
# (4, 1, 3, 9, 0, 2)

# %%
#repetition
tup1=(1,2,3)
tup1*3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %% [markdown]
# # Using some functions in tuple

# %%
tup=(1,4,5,2,3,44,-34)

# %%
len(tup)
# Out:
# 7

# %%
max({1,5,0,2})
# Out:
# 5

# %%
max(tup)
# Out:
# 44

# %%
min(tup)
sorted([1,11,4,2,3454],reverse=True)
# Out:
# [3454, 11, 4, 2, 1]

# %%
sorted(tup,reverse = True)
# Out:
# [0, 1, 2, 3, 4, 5, 44]

# %% [markdown]
# # Converting tuple into a list

# %%
#typecasting a tuple to list 
tup=(1,2,4)
newlis=list(tup)
type(newlis)
newlis
# Out:
# [1, 2, 4]

# %%
#typecasting a list into tuple 
p=[1,2,3]
print(type(p))

tul=tuple(p)
print(type(tul))
# Out:
# <class 'list'>
# <class 'tuple'>

# %% [markdown]
# # Packing and unpacking tuple

# %%
load = (1,3,5,22,81)
petti1,petti2,petti3,petti4,petti5 = load
petti5
# Out:
# 81

# %%
load_tup = (1,3,5,22,81)
load_str = "1352281"
load_list= [1,3,5,22,81]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       2 load_str = "1352281"
#       3 load_list= [1,3,5,22,81]
# ----> 5 load_str[3] = "3243"
#       6 load_str
#
# TypeError: 'str' object does not support item assignment

# %%
a,b,c=(1,2,3)
print(type(a),type(b),type(c))
# Out:
# <class 'int'> <class 'int'> <class 'int'>

# %% [markdown]
# # Nested tuples

# %%
nes=(1,2,(4,5,6),3.8)
for i in nes:
    print(i)
# Out:
# 1
# 2
# (4, 5, 6)
# 3.8

# %% [markdown]
# # Using count Object

# %%
a=(9,3,4,3,9,9)
a.count(4)
# Out:
# 1

# %% [markdown]
# # Using index Object

# %%
a.index(3)
# Out:
# 1

# %% [markdown]
# # Deleting a tuple

# %%
a=(1,2)
del(a)
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11612\901519772.py in <module>
#       1 a=(1,2)
#       2 del(a)
# ----> 3 a
#
# NameError: name 'a' is not defined

# %% [markdown]
# # Excersices on tuples

# %% [raw]
# Create a tuple which has three elements in it and unpack it with three variables.

# %% [raw]
# Create a tuple containing the names of your five favorite fruits. Print the tuple, and then print the third fruit in the tuple.

# %% [raw]
# Create a tuple containing the numbers from 1 to 10. Use a slice to print the first five numbers, and then use a slice to print the last five numbers.

# %% [raw]
# Create a tuple containing the names of five cities. Use the max() function to find the city with the longest name, and then use the min() function to find the city with the shortest name.
