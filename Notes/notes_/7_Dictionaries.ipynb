# %% [markdown]
# # Dictionary

# %% [raw]
# 1. Dictionaries are key value pairs
# 2. Dictionaries are mutable
# 3. ex {'a':12}

# %%
student1 = {
    'name':'balu',
    'age':17,
    'class':12,
}
student2 = {
    'name':'Oviya',
    'age':17,
    'class':12,
}
student1


list1 = ["apple","banana","cherry","grapes"]

# {
# 0 : apple
# 1 : banana
# 2 : cherry
# 3 : grapes
# }

list1[1]
# Out:
# 'banana'

# %%
student1['name']
# Out:
# 'balu'

# %% [markdown]
# # Accessing the Values of dictionary using keys

# %%
student_ages = {
    'muthu' : 21,
    'karuppu': 22,
    'muni' : 23
}

print(student_ages['karuppu'])
# Out:
# 22

# %%
student_ages['muni']=255
student_ages
# Out:
# {'muthu': 21, 'karuppu': 22, 'muni': 255}

# %% [markdown]
# # Using the del function for deleting a dictionary

# %%
del(student['muthu'])
student
# Out:
# {'karuppu': 22, 'muni': 255}

# %%
del student
student
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13324\1237834927.py in <module>
#       1 del student
# ----> 2 student
#
# NameError: name 'student' is not defined

# %% [markdown]
# # Using some Objects in dictionary

# %%
di = {'muthu' : 21,
    'karuppu': 22,
    'muni' : 23,
     }
a = di.pop('muni') # pop returns the particular key's value and remove the (Key value) item completley from the dictionary
print(age_of_muni)
print(di)
# Out:
# 23
# {'muthu': 21, 'karuppu': 22}

# %%
di.keys()
di.values()
di.items()
di.get("muthu")
# Out:
# 21

# %%
di = {'muthu' : 2444,
    'karuppu': 22,
    'muni' : 23,
     }
print(sorted(di.values()))
# Out:
# [22, 23, 2444]

# %%
di = {'muthu' : 21,
    'karuppu': 22,
      'muni' : 23}
a=sorted(di.keys())
a
# Out:
# ['karuppu', 'muni', 'muthu']

# %%
di.values()
b=sorted(di.values())
b
# Out:
# [21, 22, 23]

# %%
for i in di.keys():
    print(i)
# Out:
# muthu
# karuppu
# muni

# %%
for i in di.values():
    print(i)
# Out:
# 52
# 12
# 24

# %%
for i in di:
    print(i)
# Out:
# muthu
# karuppu
# muni

# %%
len(di)
# Out:
# 3

# %%
str(di)
# Out:
# "{'muthu': 52, 'karuppu': 12, 'muni': 24}"

# %%
list(di)
# Out:
# ['muthu', 'karuppu', 'muni']

# %%
di = {'muthu' : 21,
    'karuppu': 22,
    'muni' : 23,
     }

print("Before clearing",di) 

di.clear()
print("After clearing",di)
# Out:
# Before clearing {'muthu': 21, 'karuppu': 22, 'muni': 23}
# After clearing {}

# %%
di = {'muthu' : 21,
    'karuppu': 22,
    'muni' : 23,
     }

print("Before deleting",di) 

del di
print("After deleting",di)
# Out:
# Before deleting {'muthu': 21, 'karuppu': 22, 'muni': 23}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 9
#       6 print("Before deleting",di)
#       8 del di
# ----> 9 print("After deleting",di)
#
# NameError: name 'di' is not defined

# %%
di = {'muthu' : 52,
    'karuppu': 12,
      'muni' : 24}
l=di.copy()
l
# Out:
# {'muthu': 52, 'karuppu': 12, 'muni': 24}

# %%
di.items()
# Out:
# dict_items([('muthu', 52), ('karuppu', 12), ('muni', 24)])

# %%
marvel = {'muthu' : 52,
    'karuppu': 12,
      'muni' : 24}

marvel={'hela':34,
    'america':96}

marvel.update(marvel)

'''
{'hela':34,
    'america':96} + {'hela':34,
    'america':96}
'''

marvel
# Out:
# {'hela': 34, 'america': 96}

# %%
new_marvel={'roger':12}
new_marvel+marvel
new_marvel
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6752\3351492183.py in <module>
#       1 new_marvel={'roger':12}
# ----> 2 new_marvel+marvel
#       3 new_marvel
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
marvel = {'muthu' : 52,
    'karuppu': 12,
      'muni' : 24}
      
print("muthu" in marvel)
# Out:
# True

# %%
marvel = {'muthu' : 52,
    'karuppu': 12,
      'muni' : 24}
      
'muni' not in marvel
# Out:
# False

# %% [markdown]
# # Set

# %%
list1 = [1,2,2,2,2,2,2,2,3] # remove duplicates from list 
print(list(set(list1)))


set1 = {1,2,2,2,2,2,2,2,3}
set1
# Out:
# [1, 2, 3]
# {1, 2, 3}

# %%
a=[4, 3, 3,3, 2, 1,3,2]
for i in a:
    x=a.count(i)
    if x>1:
       for j in range(x-1):
         a.remove(i)
sorted(a)
# Out:
# [1, 2, 3, 4]

# %%
a=[4, 3, 3,3, 2, 1,3,2]
print(list(set(a)))
# Out:
# [1, 2, 3, 4]

# %%
type(set1)
# Out:
# set

# %%
type(di)
# Out:
# dict

# %%
len(set1)
# Out:
# 5

# %%
set1.add(1.5)
set1
# Out:
# {1, 1.5, 2, 4, 'black', 'red'}

# %%
set2={False,1,11,'str'}
set1.update(set2)
set1
# Out:
# {1, 1.5, 11, 2, 4, False, 'black', 'red', 'str'}

# %%
set2={False,1,11,'str'}

set2.remove(1)
set2
# Out:
# {11, False, 'str'}

# %%
set2.discard(2)
set2
# Out:
# {11, False, 'str'}

# %%
set1={1,2,3,4}
set2={4,5,6,1}

set1.intersection(set2)
# Out:
# {1, 4}

# %%
set1={1,2,3,4}
set2={4,5,6,1}
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {1, 4}
